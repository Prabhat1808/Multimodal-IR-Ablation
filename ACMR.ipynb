# %% [markdown]
# <a href="https://colab.research.google.com/github/Prabhat1808/Multimodal-IR-Ablation/blob/main/ACMR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 2.7.17

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/
# %tensorflow_version 1.x
# !ls
# Out:
# Mounted at /content/gdrive
# TensorFlow 1.x selected.
# gdrive	sample_data

# %%
# %cd gdrive/MyDrive/Multimodal-IR-Ablation/JFSE/ACMR_demo/
# !ls
# Out:
# /content/gdrive/MyDrive/Multimodal-IR-Ablation/JFSE/ACMR_demo
# data	   train_adv_crossmodal_simple_nuswide.py
# models	   train_adv_crossmodal_simple_wiki.py
# README.md  train_adv_crossmodal_triplet_wiki.py

# %%
# !python train_adv_crossmodal_simple_wiki.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [49][   1/  33] time: 87.6087, emb_loss: 13.17855072, domain_loss: 1.39303136, label_loss: 0.08469166, similar_loss: 4.67399693, dissimilar_loss: 1.76939106
# Epoch: [49][   2/  33] time: 87.6403, emb_loss: 12.79909325, domain_loss: 1.36836612, label_loss: 0.08062466, similar_loss: 4.69525719, dissimilar_loss: 2.06848049
# Epoch: [49][   3/  33] time: 87.6716, emb_loss: 12.72555542, domain_loss: 1.36741412, label_loss: 0.08252902, similar_loss: 4.44270563, dissimilar_loss: 1.49735999
# Epoch: [49][   4/  33] time: 87.7032, emb_loss: 12.47611523, domain_loss: 1.39024007, label_loss: 0.08187048, similar_loss: 4.24442816, dissimilar_loss: 2.23194385
# Epoch: [49][   5/  33] time: 87.7354, emb_loss: 12.34591675, domain_loss: 1.38869512, label_loss: 0.07852896, similar_loss: 4.46382236, dissimilar_loss: 1.45993555
# ...

# %%
# %cd ..
# !ls
# Out:
# data			    text_words_map.pkl
# models			    train_adv_crossmodal_simple_nuswide.py
# README.md		    train_adv_crossmodal_simple_wiki.py
# test_feats_transformed.pkl  train_adv_crossmodal_triplet_wiki.py
# test_img_feats.pkl	    train_img_feats.pkl
# test_img_files.pkl	    train_img_files.pkl
# test_img_words.pkl	    train_labels.pkl
# test_labels.pkl		    train_txt_files.pkl
# test_txt_files.pkl	    train_txt_vecs.pkl
# test_txt_vecs.pkl

# %%
import pickle
with open('test_img_words.pkl', 'rb') as f:
  train_img_feats = pickle.load(f)
train_img_feats
# Out:
# {'000023fbee1f2fafc7221590dbe496f6': ['zoologist',
#   'ilya',
#   'mechnikov',
#   'defense',
#   'motile',
#   'idea',
#   'larvae',
#   'claus',
#   'name',
#   'phagocyte',
#   'eat',
#   'kutos',
#   'vessel',
#   'year',
#   'water',
#   'crustacean',
#   'daphnia',
#   'transparent',
#   'animal',
#   'destroyed',
#   'blood',
#   'bacterium',
#   'bacillus',
#   'process',
#   'phagocytosis',
#   'mechnikov',
#   'defense',
#   'phagocytosis',
#   'opson',
#   'mechnikov',
#   'nobel',
#   'prize',
#   'physiology',
#   'medicine',
#   'work',
#   'importance',
#   'century',
#   'system'],
#  '003a2e19de70cfc0a5cb9ff19306cf40': ['leshan',
#   'giant',
#   'buddha',
#   'tang',
#   'empire',
#   'height',
#   'power',
#   'century',
#   'shi',
#   'rebellion',
#   'prosperity',
#   'empire',
#   'half',
#   'turk',
#   'tang',
#   'commander',
#   'experience',
#   'fighting',
#   'victory',
#   'responsibility',
#   'hebei',
#   'army',
#   'thousand',
#   'luoyang',
# ...

# %%
len(train_img_feats)
# Out:
# 693
